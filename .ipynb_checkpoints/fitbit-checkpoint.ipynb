# 122243  10/8/2017 11:59:36 PM     59
# 122244  10/8/2017 11:59:46 PM     58
# 122245  10/8/2017 11:59:51 PM     59
# 122246  10/8/2017 11:59:56 PM     60
#
# [122247 rows x 2 columns]

# %%
heart_data = heart['Value']
heart_data.plot(figsize = (20,8))

# %%
mean = heart_data.mean()
std = heart_data.std()
mean,std
# Out:
# (64.21758407159275, 13.27116097054837)

# %%
heart_data = heart_data.apply(lambda x : (x - mean) / std)
heart_data.head()
# Out:
# 0   -0.543855
# 1   -0.468503
# 2   -0.468503
# 3   -0.468503
# 4   -0.468503
# Name: Value, dtype: float64

# %%
features = []
y = []

window_size = 30
predicted_size = 1

for i in range(heart_data.shape[0] - window_size - predicted_size):
    features.append(heart_data[i:i+window_size])
    y.append(heart_data[i+ window_size])
features, y = np.array(features), np.array(y)
features = np.reshape(features, (features.shape[0], features.shape[1], 1))

# %%
split_index = int(features.shape[0]*(1-0.2))
X_train, X_test = features[0:split_index],features[split_index:]
y_train,y_test = y[0:split_index],y[split_index:]

X_train.shape, y_train.shape
# Out:
# ((97772, 30, 1), (97772,))

# %%
model = Sequential()

model.add(LSTM(units = 30, return_sequences = True, input_shape = (window_size, 1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 20, return_sequences = True))
model.add(Dropout(0.2))

model.add(LSTM(units = 10, return_sequences = False))
model.add(Dropout(0.2))

model.add(Dense(units = 1))

model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(
    X_train, 
    y_train, 
    epochs = 3, 
    batch_size = 512
)
# Out:
# Epoch 1/3
# 97772/97772 [==============================] - 21s 212us/step - loss: 0.2110
# Epoch 2/3
# 97772/97772 [==============================] - 19s 190us/step - loss: 0.0842
# Epoch 3/3
# 97772/97772 [==============================] - 19s 191us/step - loss: 0.0660

# %%
with open("heart_model.pkl","wb") as f:
    pkl.dump(model,f)

# %%
with open("heart_model.pkl","rb") as f:
    heart_model = pkl.load(f)

# %%
predict_heart = model.predict(X_test)

# %%
predict_heart.shape,y_test.shape
# Out:
# ((24444, 1), (24444,))

# %%
plt.figure(figsize = (20,4))
plt.plot(predict_heart,color='red', label='prediction')
plt.plot(y_test,color='blue', label='y_test')
plt.legend(loc='upper left')
plt.show()

# %%
my_heart = pd.read_csv("heart.csv",names = ["Time","Value"])["Value"]

# %%
my_heart
# Out:
# 0     70
# 1     70
# 2     70
# 3     90
# 4     91
# 5     86
# 6     85
# 7     82
# 8     81
# 9     81
# 10    81
# 11    83
# 12    83
# 13    83
# 14    74
# 15    70
# 16    70
# 17    70
# 18    73
# 19    73
# 20    73
# 21    74
# 22    73
# 23    73
# 24    74
# 25    75
# 26    75
# 27    76
# 28    74
# 29    75
# 30    75
# 31    74
# 32    74
# 33    74
# 34    75
# 35    75
# 36    75
# 37    75
# 38    76
# 39    77
# 40    78
# 41    78
# 42    76
# 43    75
# 44    75
# 45    74
# 46    70
# 47    70
# 48    70
# 49    70
# 50    70
# 51    70
# 52    70
# 53    70
# 54    71
# Name: Value, dtype: int64

# %%
my_heart = my_heart.apply(lambda x : (x - mean) / std)
my_heart
# Out:
# 0     0.435713
# 1     0.435713
# 2     0.435713
# 3     1.942740
# 4     2.018091
# 5     1.641335
# 6     1.565983
# 7     1.339929
# 8     1.264578
# 9     1.264578
# 10    1.264578
# 11    1.415281
# 12    1.415281
# 13    1.415281
# 14    0.737118
# 15    0.435713
# 16    0.435713
# 17    0.435713
# 18    0.661767
# 19    0.661767
# 20    0.661767
# 21    0.737118
# 22    0.661767
# 23    0.661767
# 24    0.737118
# 25    0.812470
# 26    0.812470
# 27    0.887821
# 28    0.737118
# 29    0.812470
# 30    0.812470
# 31    0.737118
# 32    0.737118
# 33    0.737118
# 34    0.812470
# 35    0.812470
# 36    0.812470
# 37    0.812470
# 38    0.887821
# 39    0.963172
# 40    1.038524
# 41    1.038524
# 42    0.887821
# 43    0.812470
# 44    0.812470
# 45    0.737118
# 46    0.435713
# 47    0.435713
# 48    0.435713
# 49    0.435713
# 50    0.435713
# 51    0.435713
# 52    0.435713
# 53    0.435713
# 54    0.511064
# Name: Value, dtype: float64

# %%
features = []
y = []

window_size = 30
predicted_size = 1

for i in range(my_heart.shape[0] - window_size - predicted_size):
    features.append(my_heart[i:i+window_size])
    y.append(my_heart[i+ window_size])
features, y = np.array(features), np.array(y)
features = np.reshape(features, (features.shape[0], features.shape[1], 1))

# %%
features.shape,y.shape
# Out:
# ((24, 30, 1), (24,))

# %%
predicted_my_heart = model.predict(features)

# %%
plt.figure(figsize = (20,4))
plt.plot(predicted_my_heart[1:],color='red', label='prediction')
plt.plot(y[:-1],color='blue', label='y_test')
plt.legend(loc='upper left')
plt.show()

# %%
predicted_my_heart = predicted_my_heart.reshape(predicted_my_heart.shape[0])

# %%
from scipy.stats import pearsonr
print(pearsonr(predicted_my_heart[1:],y[:-1])[0])
# Out:
# 0.9430232216906873

# %%
adjusted_predicted = (predicted_my_heart * std ) + mean
adjusted_predicted = adjusted_predicted.reshape((adjusted_predicted.shape[0])).tolist()

# %%
adjusted_predicted
# Out:
# [74.55339050292969,
#  74.37728118896484,
#  73.9949951171875,
#  73.55652618408203,
#  73.23191833496094,
#  73.34298706054688,
#  73.76734924316406,
#  74.24281311035156,
#  74.56756591796875,
#  74.9399642944336,
#  75.56554412841797,
#  76.50190734863281,
#  77.3751449584961,
#  77.29088592529297,
#  76.21541595458984,
#  74.88500213623047,
#  73.65806579589844,
#  71.93933868408203,
#  70.24946594238281,
#  69.0712661743164,
#  68.57154083251953,
#  68.64734649658203,
#  69.05096435546875,
#  69.51918029785156]

# %%
predicted = (y[:-1]* std + mean).values.tolist()
